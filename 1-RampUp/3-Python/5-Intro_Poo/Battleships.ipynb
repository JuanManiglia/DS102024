# %% [markdown]
# Crea una versión simplificada del clásico juego "Battleship" utilizando Programación Orientada a Objetos (POO). El juego se desarrollará en la consola y consistirá en lo siguiente:
#
# # Reglas del Juego:
# El tablero será de tamaño 10x10.
# Cada jugador tendrá 5 barcos de diferentes tamaños:
# 1 portaaviones (tamaño 5)
# 1 acorazado (tamaño 4)
# 1 crucero (tamaño 3)
# 1 submarino (tamaño 3)
# 1 destructor (tamaño 2)
# Los barcos podrán colocarse tanto en posición horizontal como vertical.
# Durante el turno de un jugador, este deberá elegir una coordenada para atacar (fila y columna). Si acierta, el barco atacado recibirá un golpe. Si se destruyen todas las partes de un barco, este se considerará hundido.
# El juego termina cuando un jugador logra hundir todos los barcos del oponente.
#
# # Requisitos del Programa:
#
# ## 1. Clases
#
# Debes implementar las siguientes clases con sus respectivos atributos y métodos:
#
# ### Clase Tablero: Representará el tablero del jugador y el estado de sus barcos.
#
# Atributos:
# tablero: Matriz 10x10 que representará el tablero del jugador.
# barcos: Lista de objetos Barco colocados en el tablero.
#
# Métodos:
# colocar_barco(barco, posicion, orientacion): Coloca un barco en el tablero.
# recibir_ataque(fila, columna): Actualiza el estado del tablero tras recibir un ataque en las coordenadas indicadas y devuelve si fue un golpe o un fallo.
# mostrar_tablero(): Muestra el tablero en consola.
# todos_barcos_hundidos(): Verifica si todos los barcos han sido hundidos.
#
# ### Clase Barco: Representa un barco en el juego.
#
# Atributos:
# nombre: Nombre del barco.
# tamano: Longitud del barco.
# posicion: Lista de posiciones ocupadas por el barco en el tablero.
# golpes: Número de veces que el barco ha sido atacado.
#
# Métodos:
# recibir_golpe(): Incrementa el contador de golpes en el barco.
# esta_hundido(): Devuelve si el barco ha sido hundido.
#
# ### Clase Jugador: Representa a un jugador en el juego.
#
# Atributos:
# nombre: Nombre del jugador.
# tablero: Objeto de la clase Tablero que representa el tablero del jugador.
#
# Métodos:
# atacar(oponente, fila, columna): Realiza un ataque en las coordenadas seleccionadas del tablero del oponente.
#
# ## 2. Lógica del Juego
#
# Crea una clase Juego que controle la interacción entre dos jugadores.
#
# Métodos:
# iniciar_juego(): Inicia la partida entre dos jugadores, alternando los turnos hasta que uno de ellos gane.
# turno(jugador): Ejecuta el turno de un jugador, permitiendo seleccionar coordenadas de ataque y mostrar el resultado.
#
# Detalles Adicionales:
# La colocación de los barcos debe verificar que no se superpongan entre sí ni salgan del límite del tablero.
# Los jugadores no deben poder atacar la misma coordenada más de una vez.
# Proporciona una forma visual sencilla de mostrar el estado del tablero en la consola, usando símbolos como O para agua, X para golpe, y B para barco.

# %%
#Creación clase barco

class Barco:
    def __init__ (self, nombre, tamano):
        self.nombre = nombre #nombre del barco
        self.tamano = tamano #longitud del barco
        self.posicion = posicion #posicion del barco 
        self.golpes = golpes # número de golpes que recibirá el barco

posicion = [] #lista de posiciones ocupadas por el barco en el tablero
golpes = 0 #número de veces que el barco ha sido atacado


#tipos de barcos en el juego
portaaviones = Barco ("Portaaviones", 5) #1 portaaviones (tamaño 5)
acorazado = Barco ("Acorazado", 4) # 1 acorazado (tamaño 4)
crucero = Barco ("Crucero", 3) # 1 crucero (tamaño 3)
submarino = Barco ("Submarino", 3) # 1 submarino (tamaño 3)
destructor = Barco ("Destructor", 2) # 1 destructor (tamaño 2)


#Métodos:
#recibir_golpe(): Incrementa el contador de golpes en el barco.
def recibir_golpe (self):
    self.golpes += 1

#esta_hundido(): Devuelve si el barco ha sido hundido.
def esta_hundido(self):
    return self.golpes >= self.tamano

# %%
#Creación clase Tablero: Representará el tablero del jugador y el estado de sus barcos.

class Tablero:
    def __init__(self, fila=10, columna=10):
        self.fila = fila #tablero: Matriz 10x10 que representará el tablero del jugador.
        self.columna = columna
        self.barcos=[] # barcos: Lista de objetos Barco colocados en el tablero.


#colocar_barco(barco, posicion, orientacion): Coloca un barco en el tablero.
def colocar_barco (self, barco, fila, columna, orientacion):
    self.barco = barco
    self.fila = fila
    self.columna = columna
    self.orientacion = orientacion


#recibir_ataque(fila, columna): Actualiza el estado del tablero tras recibir un ataque en las coordenadas indicadas y devuelve si fue un golpe o un fallo.



#mostrar_tablero(): Muestra el tablero en consola.



#todos_barcos_hundidos(): Verifica si todos los barcos han sido hundidos.

# %%
#Creación clase Jugador: Representa a un jugador en el juego.

class Jugador:
    def __init__(self, nombre, tablero_jugador):
        self.nombre = nombre #nombre: Nombre del jugador.
        self.tablero_jugador = tablero_jugador #Objeto de la clase Tablero que representa el tablero del jugador


#Métodos:
#atacar(oponente, fila, columna): Realiza un ataque en las coordenadas seleccionadas del tablero del oponente.

# %%
#Creación clase Juego que controle la interacción entre dos jugadores.

class Juego:


#Métodos:
#iniciar_juego(): Inicia la partida entre dos jugadores, alternando los turnos hasta que uno de ellos gane.



#turno(jugador): Ejecuta el turno de un jugador, permitiendo seleccionar coordenadas de ataque y mostrar el resultado.

# %%
#Detalles Adicionales:
#La colocación de los barcos debe verificar que no se superpongan entre sí ni salgan del límite del tablero.
#Los jugadores no deben poder atacar la misma coordenada más de una vez.
#Proporciona una forma visual sencilla de mostrar el estado del tablero en la consola, usando símbolos como O para agua, X para golpe, y B para barco.
