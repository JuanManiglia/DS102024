# %% [markdown]
# ## Ejercicio 1: Ortogonalidad

# %% [markdown]
# Definir una función en python que detecte si dos vectores son ortogonales

# %%
import numpy as np
def son_ortogonales(u,v):
  if len(u) != len(v):
        raise ValueError("Los vectores deben tener la misma dimensión.")
    
producto_escalar = sum(a * b for a, b in zip(u, v))
return producto_escalar == 0
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[5], line 6
#       3   if len(u) != len(v):
#       4         raise ValueError("Los vectores deben tener la misma dimensión.")
# ----> 6 producto_escalar = sum(a * b for a, b in zip(u, v))
#       7 return producto_escalar == 0
#
# NameError: name 'u' is not defined

# %% [markdown]
# ## Ejercicio 2: Desplazamiento

# %% [markdown]
# Definir una función en python que reciba como parámetro las cuatro esquinas de un cuadrilátero y las desplace 5 unidades hacia arriba y 7 unidades a la izquierda

# %%
def desplazar_puntos(a,b,c,d):
    if len(esquinas) != 4:
        raise ValueError("Se deben proporcionar exactamente 4 esquinas.")
    

    nuevas_esquinas = [(x - 7, y + 5) for x, y in esquinas]
    return nuevas_esquinas

# %% [markdown]
# Ejecutar la siguiente celda descomentando las lineas en verde para verificar su funcionamiento.

# %%
import matplotlib.pyplot as plt
a = np.array([1,1])
b = np.array([1,2])
c = np.array([2,3])
d = np.array([8,4])

x_coords, y_coords = zip(a,b,c,d,a)
plt.plot(x_coords, y_coords, "c--", x_coords, y_coords, "co")

a_,b_,c_,d_ = desplazar_puntos(a,b,c,d)
x_coords_b, y_coords_b = zip(a_,b_,c_,d_,a_)
plt.plot(x_coords_b, y_coords_b, "b-", x_coords_b, y_coords_b, "bo")

plt.show()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[6], line 10
#       7 x_coords, y_coords = zip(a,b,c,d,a)
#       8 plt.plot(x_coords, y_coords, "c--", x_coords, y_coords, "co")
# ---> 10 a_,b_,c_,d_ = desplazar_puntos(a,b,c,d)
#      11 x_coords_b, y_coords_b = zip(a_,b_,c_,d_,a_)
#      12 plt.plot(x_coords_b, y_coords_b, "b-", x_coords_b, y_coords_b, "bo")
#
# NameError: name 'desplazar_puntos' is not defined
