# %% [markdown]
# # Tips

# %% [markdown]
# ### Paso 1. Importe las bibliotecas necesarias:

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
# establecer el estilo seaborn en blanco
sns.set_style("white")

# %% [markdown]
# ### Paso 2. Importar el conjunto de datos de esta [dirección](https://raw.githubusercontent.com/guipsamora/pandas_exercises/master/07_Visualization/Tips/tips.csv).

# %%
df=pd.read_csv("https://raw.githubusercontent.com/guipsamora/pandas_exercises/master/07_Visualization/Tips/tips.csv")

# %% [markdown]
# ### Paso 3. Asignarlo a una variable llamada tips

# %%
tips=df
tips
# Out:
#      Unnamed: 0  total_bill   tip     sex smoker   day    time  size
# 0             0       16.99  1.01  Female     No   Sun  Dinner     2
# 1             1       10.34  1.66    Male     No   Sun  Dinner     3
# 2             2       21.01  3.50    Male     No   Sun  Dinner     3
# 3             3       23.68  3.31    Male     No   Sun  Dinner     2
# 4             4       24.59  3.61  Female     No   Sun  Dinner     4
# ..          ...         ...   ...     ...    ...   ...     ...   ...
# 239         239       29.03  5.92    Male     No   Sat  Dinner     3
# 240         240       27.18  2.00  Female    Yes   Sat  Dinner     2
# 241         241       22.67  2.00    Male    Yes   Sat  Dinner     2
# 242         242       17.82  1.75    Male     No   Sat  Dinner     2
# 243         243       18.78  3.00  Female     No  Thur  Dinner     2
#
# [244 rows x 8 columns]

# %% [markdown]
# ### Paso 4. Trazar el histograma de la columna ``total_bill``

# %%
sns.histplot(df["total_bill"])

plt.xlabel("Total Bill")
plt.ylabel("Frecuencia")
plt.title("Total Bill")

plt.show()

# %% [markdown]
# ### Paso 5. Cree un gráfico de dispersión que presente la relación entre ``total_bill`` y ``tip``

# %%
sns.scatterplot(x="total_bill", y="tip", data=tips)
plt.title("Gráfico de Dispersión")
plt.xlabel("Total Bill")
plt.ylabel("Tip")

plt.show()

# %% [markdown]
# ### Paso 6.  Crear una imagen con la relación de `total_bill`, `tip` y `size`.
# #### Sugerencia: es sólo una función.

# %%
fig=plt.figure()
ax=fig.add_subplot(111, projection="3d")
ax.scatter("total_bill", "tip", "size", c="r", marker="o")
plt.show()
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[18], line 3
#       1 fig=plt.figure()
#       2 ax=fig.add_subplot(111, projection="3d")
# ----> 3 ax.scatter("total_bill", "tip", "size", c="r", marker="o")
#       4 plt.show()
#
# File c:\Users\kimbe\AppData\Local\pypoetry\Cache\virtualenvs\bootcamp-ds-gDITtNOb-py3.11\Lib\site-packages\matplotlib\__init__.py:1521, in _preprocess_data.<locals>.inner(ax, data, *args, **kwargs)
#    1518 @functools.wraps(func)
#    1519 def inner(ax, *args, data=None, **kwargs):
#    1520     if data is None:
# -> 1521         return func(
#    1522             ax,
#    1523             *map(cbook.sanitize_sequence, args),
#    1524             **{k: cbook.sanitize_sequence(v) for k, v in kwargs.items()})
#    1526     bound = new_sig.bind(ax, *args, **kwargs)
#    1527     auto_label = (bound.arguments.get(label_namer)
#    1528                   or bound.kwargs.get(label_namer))
#
# File c:\Users\kimbe\AppData\Local\pypoetry\Cache\virtualenvs\bootcamp-ds-gDITtNOb-py3.11\Lib\site-packages\mpl_toolkits\mplot3d\axes3d.py:2967, in Axes3D.scatter(self, xs, ys, zs, zdir, s, c, depthshade, axlim_clip, *args, **kwargs)
#    2964 if self._zmargin < 0.05 and xs.size > 0:
#    2965     self.set_zmargin(0.05)
# -> 2967 self.auto_scale_xyz(xs, ys, zs, had_data)
#    2969 return patches
#
# File c:\Users\kimbe\AppData\Local\pypoetry\Cache\virtualenvs\bootcamp-ds-gDITtNOb-py3.11\Lib\site-packages\mpl_toolkits\mplot3d\axes3d.py:601, in Axes3D.auto_scale_xyz(self, X, Y, Z, had_data)
#     597 def auto_scale_xyz(self, X, Y, Z=None, had_data=None):
#     598     # This updates the bounding boxes as to keep a record as to what the
#     599     # minimum sized rectangular volume holds the data.
#     600     if np.shape(X) == np.shape(Y):
# --> 601         self.xy_dataLim.update_from_data_xy(
#     602             np.column_stack([np.ravel(X), np.ravel(Y)]), not had_data)
#     603     else:
#     604         self.xy_dataLim.update_from_data_x(X, not had_data)
#
# File c:\Users\kimbe\AppData\Local\pypoetry\Cache\virtualenvs\bootcamp-ds-gDITtNOb-py3.11\Lib\site-packages\matplotlib\transforms.py:942, in Bbox.update_from_data_xy(self, xy, ignore, updatex, updatey)
#     939 if len(xy) == 0:
#     940     return
# --> 942 path = Path(xy)
#     943 self.update_from_path(path, ignore=ignore,
#     944                       updatex=updatex, updatey=updatey)
#
# File c:\Users\kimbe\AppData\Local\pypoetry\Cache\virtualenvs\bootcamp-ds-gDITtNOb-py3.11\Lib\site-packages\matplotlib\path.py:129, in Path.__init__(self, vertices, codes, _interpolation_steps, closed, readonly)
#      99 def __init__(self, vertices, codes=None, _interpolation_steps=1,
#     100              closed=False, readonly=False):
#     101     """
#     102     Create a new path with the given vertices and codes.
#     103
#    (...)
#     127         and codes as read-only arrays.
#     128     """
# --> 129     vertices = _to_unmasked_float_array(vertices)
#     130     _api.check_shape((None, 2), vertices=vertices)
#     132     if codes is not None and len(vertices):
#
# File c:\Users\kimbe\AppData\Local\pypoetry\Cache\virtualenvs\bootcamp-ds-gDITtNOb-py3.11\Lib\site-packages\matplotlib\cbook.py:1345, in _to_unmasked_float_array(x)
#    1343     return np.ma.asarray(x, float).filled(np.nan)
#    1344 else:
# -> 1345     return np.asarray(x, float)
#
# ValueError: could not convert string to float: np.str_('total_bill')
# Error in callback <function _draw_all_if_interactive at 0x000001DFB79A3380> (for post_execute), with arguments args (),kwargs {}:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# File c:\Users\kimbe\AppData\Local\pypoetry\Cache\virtualenvs\bootcamp-ds-gDITtNOb-py3.11\Lib\site-packages\matplotlib\pyplot.py:279, in _draw_all_if_interactive()
#     277 def _draw_all_if_interactive() -> None:
#     278     if matplotlib.is_interactive():
# --> 279         draw_all()
#
# File c:\Users\kimbe\AppData\Local\pypoetry\Cache\virtualenvs\bootcamp-ds-gDITtNOb-py3.11\Lib\site-packages\matplotlib\_pylab_helpers.py:131, in Gcf.draw_all(cls, force)
#     129 for manager in cls.get_all_fig_managers():
#     130     if force or manager.canvas.figure.stale:
# --> 131         manager.canvas.draw_idle()
#
# File c:\Users\kimbe\AppData\Local\pypoetry\Cache\virtualenvs\bootcamp-ds-gDITtNOb-py3.11\Lib\site-packages\matplotlib\backend_bases.py:1891, in FigureCanvasBase.draw_idle(self, *args, **kwargs)
#    1889 if not self._is_idle_drawing:
#    1890     with self._idle_draw_cntx():
# -> 1891         self.draw(*args, **kwargs)
#
# File c:\Users\kimbe\AppData\Local\pypoetry\Cache\virtualenvs\bootcamp-ds-gDITtNOb-py3.11\Lib\site-packages\matplotlib\backends\backend_agg.py:382, in FigureCanvasAgg.draw(self)
#     379 # Acquire a lock on the shared font cache.
#     380 with (self.toolbar._wait_cursor_for_draw_cm() if self.toolbar
#     381       else nullcontext()):
# --> 382     self.figure.draw(self.renderer)
#     383     # A GUI class may be need to update a window using this draw, so
#     384     # don't forget to call the superclass.
#     385     super().draw()
#
# File c:\Users\kimbe\AppData\Local\pypoetry\Cache\virtualenvs\bootcamp-ds-gDITtNOb-py3.11\Lib\site-packages\matplotlib\artist.py:94, in _finalize_rasterization.<locals>.draw_wrapper(artist, renderer, *args, **kwargs)
#      92 @wraps(draw)
#      93 def draw_wrapper(artist, renderer, *args, **kwargs):
# ---> 94     result = draw(artist, renderer, *args, **kwargs)
#      95     if renderer._rasterizing:
#      96         renderer.stop_rasterizing()
#
# File c:\Users\kimbe\AppData\Local\pypoetry\Cache\virtualenvs\bootcamp-ds-gDITtNOb-py3.11\Lib\site-packages\matplotlib\artist.py:71, in allow_rasterization.<locals>.draw_wrapper(artist, renderer)
#      68     if artist.get_agg_filter() is not None:
#      69         renderer.start_filter()
# ---> 71     return draw(artist, renderer)
#      72 finally:
#      73     if artist.get_agg_filter() is not None:
#
# File c:\Users\kimbe\AppData\Local\pypoetry\Cache\virtualenvs\bootcamp-ds-gDITtNOb-py3.11\Lib\site-packages\matplotlib\figure.py:3257, in Figure.draw(self, renderer)
#    3254             # ValueError can occur when resizing a window.
#    3256     self.patch.draw(renderer)
# -> 3257     mimage._draw_list_compositing_images(
#    3258         renderer, self, artists, self.suppressComposite)
#    3260     renderer.close_group('figure')
#    3261 finally:
#
# File c:\Users\kimbe\AppData\Local\pypoetry\Cache\virtualenvs\bootcamp-ds-gDITtNOb-py3.11\Lib\site-packages\matplotlib\image.py:134, in _draw_list_compositing_images(renderer, parent, artists, suppress_composite)
#     132 if not_composite or not has_images:
#     133     for a in artists:
# --> 134         a.draw(renderer)
#     135 else:
#     136     # Composite any adjacent images together
#     137     image_group = []
#
# File c:\Users\kimbe\AppData\Local\pypoetry\Cache\virtualenvs\bootcamp-ds-gDITtNOb-py3.11\Lib\site-packages\matplotlib\artist.py:71, in allow_rasterization.<locals>.draw_wrapper(artist, renderer)
#      68     if artist.get_agg_filter() is not None:
#      69         renderer.start_filter()
# ---> 71     return draw(artist, renderer)
#      72 finally:
#      73     if artist.get_agg_filter() is not None:
#
# File c:\Users\kimbe\AppData\Local\pypoetry\Cache\virtualenvs\bootcamp-ds-gDITtNOb-py3.11\Lib\site-packages\mpl_toolkits\mplot3d\axes3d.py:445, in Axes3D.draw(self, renderer)
#     441 zorder_offset = max(axis.get_zorder()
#     442                     for axis in self._axis_map.values()) + 1
#     443 collection_zorder = patch_zorder = zorder_offset
# --> 445 for artist in sorted(collections_and_patches,
#     446                      key=lambda artist: artist.do_3d_projection(),
#     447                      reverse=True):
#     448     if isinstance(artist, mcoll.Collection):
#     449         artist.zorder = collection_zorder
#
# File c:\Users\kimbe\AppData\Local\pypoetry\Cache\virtualenvs\bootcamp-ds-gDITtNOb-py3.11\Lib\site-packages\mpl_toolkits\mplot3d\axes3d.py:446, in Axes3D.draw.<locals>.<lambda>(artist)
#     441 zorder_offset = max(axis.get_zorder()
#     442                     for axis in self._axis_map.values()) + 1
#     443 collection_zorder = patch_zorder = zorder_offset
#     445 for artist in sorted(collections_and_patches,
# --> 446                      key=lambda artist: artist.do_3d_projection(),
#     447                      reverse=True):
#     448     if isinstance(artist, mcoll.Collection):
#     449         artist.zorder = collection_zorder
#
# File c:\Users\kimbe\AppData\Local\pypoetry\Cache\virtualenvs\bootcamp-ds-gDITtNOb-py3.11\Lib\site-packages\mpl_toolkits\mplot3d\art3d.py:858, in Path3DCollection.do_3d_projection(self)
#     856 else:
#     857     xs, ys, zs = self._offsets3d
# --> 858 vxs, vys, vzs, vis = proj3d._proj_transform_clip(xs, ys, zs,
#     859                                                  self.axes.M,
#     860                                                  self.axes._focal_length)
#     861 # Sort the points based on z coordinates
#     862 # Performance optimization: Create a sorted index array and reorder
#     863 # points and point properties according to the index array
#     864 z_markers_idx = self._z_markers_idx = np.ma.argsort(vzs)[::-1]
#
# File c:\Users\kimbe\AppData\Local\pypoetry\Cache\virtualenvs\bootcamp-ds-gDITtNOb-py3.11\Lib\site-packages\mpl_toolkits\mplot3d\proj3d.py:209, in _proj_transform_clip(xs, ys, zs, M, focal_length)
#     203 """
#     204 Transform the points by the projection matrix
#     205 and return the clipping result
#     206 returns txs, tys, tzs, tis
#     207 """
#     208 vec = _vec_pad_ones(xs, ys, zs)
# --> 209 return _proj_transform_vec_clip(vec, M, focal_length)
#
# File c:\Users\kimbe\AppData\Local\pypoetry\Cache\virtualenvs\bootcamp-ds-gDITtNOb-py3.11\Lib\site-packages\mpl_toolkits\mplot3d\proj3d.py:148, in _proj_transform_vec_clip(vec, M, focal_length)
#     147 def _proj_transform_vec_clip(vec, M, focal_length):
# --> 148     vecw = np.dot(M, vec.data)
#     149     w = vecw[3]
#     150     txs, tys, tzs = vecw[0] / w, vecw[1] / w, vecw[2] / w
#
# ValueError: data type must provide an itemsize
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# File c:\Users\kimbe\AppData\Local\pypoetry\Cache\virtualenvs\bootcamp-ds-gDITtNOb-py3.11\Lib\site-packages\IPython\core\formatters.py:402, in BaseFormatter.__call__(self, obj)
#     400     pass
#     401 else:
# --> 402     return printer(obj)
#     403 # Finally look for special method names
#     404 method = get_real_method(obj, self.print_method)
#
# File c:\Users\kimbe\AppData\Local\pypoetry\Cache\virtualenvs\bootcamp-ds-gDITtNOb-py3.11\Lib\site-packages\IPython\core\pylabtools.py:170, in print_figure(fig, fmt, bbox_inches, base64, **kwargs)
#     167     from matplotlib.backend_bases import FigureCanvasBase
#     168     FigureCanvasBase(fig)
# --> 170 fig.canvas.print_figure(bytes_io, **kw)
#     171 data = bytes_io.getvalue()
#     172 if fmt == 'svg':
#
# File c:\Users\kimbe\AppData\Local\pypoetry\Cache\virtualenvs\bootcamp-ds-gDITtNOb-py3.11\Lib\site-packages\matplotlib\backend_bases.py:2155, in FigureCanvasBase.print_figure(self, filename, dpi, facecolor, edgecolor, orientation, format, bbox_inches, pad_inches, bbox_extra_artists, backend, **kwargs)
#    2152     # we do this instead of `self.figure.draw_without_rendering`
#    2153     # so that we can inject the orientation
#    2154     with getattr(renderer, "_draw_disabled", nullcontext)():
# -> 2155         self.figure.draw(renderer)
#    2156 if bbox_inches:
#    2157     if bbox_inches == "tight":
#
# File c:\Users\kimbe\AppData\Local\pypoetry\Cache\virtualenvs\bootcamp-ds-gDITtNOb-py3.11\Lib\site-packages\matplotlib\artist.py:94, in _finalize_rasterization.<locals>.draw_wrapper(artist, renderer, *args, **kwargs)
#      92 @wraps(draw)
#      93 def draw_wrapper(artist, renderer, *args, **kwargs):
# ---> 94     result = draw(artist, renderer, *args, **kwargs)
#      95     if renderer._rasterizing:
#      96         renderer.stop_rasterizing()
#
# File c:\Users\kimbe\AppData\Local\pypoetry\Cache\virtualenvs\bootcamp-ds-gDITtNOb-py3.11\Lib\site-packages\matplotlib\artist.py:71, in allow_rasterization.<locals>.draw_wrapper(artist, renderer)
#      68     if artist.get_agg_filter() is not None:
#      69         renderer.start_filter()
# ---> 71     return draw(artist, renderer)
#      72 finally:
#      73     if artist.get_agg_filter() is not None:
#
# File c:\Users\kimbe\AppData\Local\pypoetry\Cache\virtualenvs\bootcamp-ds-gDITtNOb-py3.11\Lib\site-packages\matplotlib\figure.py:3257, in Figure.draw(self, renderer)
#    3254             # ValueError can occur when resizing a window.
#    3256     self.patch.draw(renderer)
# -> 3257     mimage._draw_list_compositing_images(
#    3258         renderer, self, artists, self.suppressComposite)
#    3260     renderer.close_group('figure')
#    3261 finally:
#
# File c:\Users\kimbe\AppData\Local\pypoetry\Cache\virtualenvs\bootcamp-ds-gDITtNOb-py3.11\Lib\site-packages\matplotlib\image.py:134, in _draw_list_compositing_images(renderer, parent, artists, suppress_composite)
#     132 if not_composite or not has_images:
#     133     for a in artists:
# --> 134         a.draw(renderer)
#     135 else:
#     136     # Composite any adjacent images together
#     137     image_group = []
#
# File c:\Users\kimbe\AppData\Local\pypoetry\Cache\virtualenvs\bootcamp-ds-gDITtNOb-py3.11\Lib\site-packages\matplotlib\artist.py:71, in allow_rasterization.<locals>.draw_wrapper(artist, renderer)
#      68     if artist.get_agg_filter() is not None:
#      69         renderer.start_filter()
# ---> 71     return draw(artist, renderer)
#      72 finally:
#      73     if artist.get_agg_filter() is not None:
#
# File c:\Users\kimbe\AppData\Local\pypoetry\Cache\virtualenvs\bootcamp-ds-gDITtNOb-py3.11\Lib\site-packages\mpl_toolkits\mplot3d\axes3d.py:445, in Axes3D.draw(self, renderer)
#     441 zorder_offset = max(axis.get_zorder()
#     442                     for axis in self._axis_map.values()) + 1
#     443 collection_zorder = patch_zorder = zorder_offset
# --> 445 for artist in sorted(collections_and_patches,
#     446                      key=lambda artist: artist.do_3d_projection(),
#     447                      reverse=True):
#     448     if isinstance(artist, mcoll.Collection):
#     449         artist.zorder = collection_zorder
#
# File c:\Users\kimbe\AppData\Local\pypoetry\Cache\virtualenvs\bootcamp-ds-gDITtNOb-py3.11\Lib\site-packages\mpl_toolkits\mplot3d\axes3d.py:446, in Axes3D.draw.<locals>.<lambda>(artist)
#     441 zorder_offset = max(axis.get_zorder()
#     442                     for axis in self._axis_map.values()) + 1
#     443 collection_zorder = patch_zorder = zorder_offset
#     445 for artist in sorted(collections_and_patches,
# --> 446                      key=lambda artist: artist.do_3d_projection(),
#     447                      reverse=True):
#     448     if isinstance(artist, mcoll.Collection):
#     449         artist.zorder = collection_zorder
#
# File c:\Users\kimbe\AppData\Local\pypoetry\Cache\virtualenvs\bootcamp-ds-gDITtNOb-py3.11\Lib\site-packages\mpl_toolkits\mplot3d\art3d.py:858, in Path3DCollection.do_3d_projection(self)
#     856 else:
#     857     xs, ys, zs = self._offsets3d
# --> 858 vxs, vys, vzs, vis = proj3d._proj_transform_clip(xs, ys, zs,
#     859                                                  self.axes.M,
#     860                                                  self.axes._focal_length)
#     861 # Sort the points based on z coordinates
#     862 # Performance optimization: Create a sorted index array and reorder
#     863 # points and point properties according to the index array
#     864 z_markers_idx = self._z_markers_idx = np.ma.argsort(vzs)[::-1]
#
# File c:\Users\kimbe\AppData\Local\pypoetry\Cache\virtualenvs\bootcamp-ds-gDITtNOb-py3.11\Lib\site-packages\mpl_toolkits\mplot3d\proj3d.py:209, in _proj_transform_clip(xs, ys, zs, M, focal_length)
#     203 """
#     204 Transform the points by the projection matrix
#     205 and return the clipping result
#     206 returns txs, tys, tzs, tis
#     207 """
#     208 vec = _vec_pad_ones(xs, ys, zs)
# --> 209 return _proj_transform_vec_clip(vec, M, focal_length)
#
# File c:\Users\kimbe\AppData\Local\pypoetry\Cache\virtualenvs\bootcamp-ds-gDITtNOb-py3.11\Lib\site-packages\mpl_toolkits\mplot3d\proj3d.py:148, in _proj_transform_vec_clip(vec, M, focal_length)
#     147 def _proj_transform_vec_clip(vec, M, focal_length):
# --> 148     vecw = np.dot(M, vec.data)
#     149     w = vecw[3]
#     150     txs, tys, tzs = vecw[0] / w, vecw[1] / w, vecw[2] / w
#
# ValueError: data type must provide an itemsize

# %% [markdown]
# ### Paso 7. Presente la relación entre ``days`` y ``total_bill``

# %% [markdown]
# ### Paso 8. Crear un gráfico de dispersión con el ``day`` como eje y y ``tips`` como eje x, diferenciar los puntos por ``sex``.

# %% [markdown]
# ### Paso 9.  Cree una box plot presentación del ``total_bill`` por ``day`` diferetiation el tiempo ``(Dinner or Lunch)``

# %% [markdown]
# ### Paso 10. Cree dos histogramas del valor del tip basados en Dinner y Lunch. Deben estar uno al lado del otro.

# %% [markdown]
# ### Paso 11. Cree dos gráficos de dispersión, uno para los hombres y otro para las mujeres, que presenten la relación entre el valor ``total_bill`` y la ``tip``, diferenciando entre ``smoker`` y ``no smoker``.
# ### Deben estar uno al lado del otro.
