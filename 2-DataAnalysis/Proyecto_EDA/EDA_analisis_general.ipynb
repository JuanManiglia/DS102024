# %% [markdown]
# # Análisis de Datos - Turismo Internacional en España 2019-2024
#
# ![](https://mediterrani.com/wp-content/webp-express/webp-images/uploads/2018/05/sector-turi%CC%81stico-en-espan%CC%83a.jpg.webp)

# %% [markdown]
# ## Preparación y Carga de Datos

# %% [markdown]
# ### Librerías

# %%
# Tratamiento de datos
import numpy as np
import pandas as pd

# Gráficos
import matplotlib.pyplot as plt
import plotly.express as px
import seaborn as sns

# Otros
import json

# %% [markdown]
# ## Carga de Datos

# %%
dftotal = pd.read_csv("total.csv", encoding='latin-1')

# %% [markdown]
# ## Análisis Exploratorio de Datos (EDA)

# %% [markdown]
# ### Análisis Univariante

# %%
dftotal.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3328 entries, 0 to 3327
# Data columns (total 5 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   FECHA              3328 non-null   object
#  1   PROVINCIA_DESTINO  3328 non-null   object
#  2   TURISTAS           3328 non-null   int64
#  3   PERNOCTACIONES     3328 non-null   int64
#  4   ESTANCIA_MEDIA     3328 non-null   float64
# dtypes: float64(1), int64(2), object(2)
# memory usage: 130.1+ KB

# %%
dftotal.describe(include='object')
# Out:
#           FECHA PROVINCIA_DESTINO
# count      3328              3328
# unique       64                52
# top     2019/07         A CoruÃ±a
# freq         52                64

# %%
dftotal[["TURISTAS", "PERNOCTACIONES", "ESTANCIA_MEDIA"]].describe()
# Out:
#            TURISTAS  PERNOCTACIONES  ESTANCIA_MEDIA
# count  3.328000e+03    3.328000e+03     3328.000000
# mean   1.105854e+05    8.121999e+05        8.331430
# std    2.327480e+05    1.561353e+06        2.275669
# min    1.679000e+03    2.008100e+04        3.000000
# 25%    1.481200e+04    1.259595e+05        7.000000
# 50%    3.225650e+04    2.591370e+05        8.000000
# 75%    7.976625e+04    6.267038e+05        9.000000
# max    2.428342e+06    1.578477e+07       18.000000

# %%
dftotal.min()
# Out:
# FECHA                  2019/07
# PROVINCIA_DESTINO    A CoruÃ±a
# TURISTAS                  1679
# PERNOCTACIONES           20081
# ESTANCIA_MEDIA             3.0
# dtype: object

# %%
dftotal.max()
# Out:
# FECHA                 2024/10
# PROVINCIA_DESTINO      Ãvila
# TURISTAS              2428342
# PERNOCTACIONES       15784772
# ESTANCIA_MEDIA           18.0
# dtype: object

# %% [markdown]
# Histograma

# %%
dftotal['TURISTAS'].plot(kind='hist', bins=20, alpha=0.7, title='Histograma de Turistas')
plt.savefig('hist_turista.png')
plt.show()

dftotal['PERNOCTACIONES'].plot(kind='hist', bins=20, alpha=0.7, title='Histograma de Pernoctaciones')
plt.savefig('hist_pernoctaciones_anual.png')
plt.show()

dftotal['ESTANCIA_MEDIA'].plot(kind='hist', bins=20, alpha=0.7, title='Histograma de Estancia_Media')
plt.savefig('hist_estancia_media_anual.png')
plt.show()

# %%
plt.hist2d(dftotal["TURISTAS"], dftotal["ESTANCIA_MEDIA"], bins=(5, 5), cmap="Blues", cmin=5)
plt.colorbar(label="Frecuencia")
plt.title("Histograma 2D: Turistas vs Estancia Media")
plt.xlabel("Número de Turistas")
plt.ylabel("Estancia Media (días)")
plt.grid(alpha=0.5)
plt.savefig('hist2D.png')
plt.show()

# %% [markdown]
# Scatter Plots

# %%
sns.scatterplot(data=dftotal, x='FECHA', y='TURISTAS')
plt.savefig('scatter_turista.png')
plt.show()

# %%
sns.scatterplot(data=dftotal, x='FECHA', y='PERNOCTACIONES')
plt.savefig('scatter_pernoctaciones.png')
plt.show()

# %%
sns.scatterplot(data=dftotal, x='FECHA', y='ESTANCIA_MEDIA')
plt.savefig('scatter_estancia_media.png')
plt.show()

# %%
sns.scatterplot(data=dftotal, x='ESTANCIA_MEDIA', y='TURISTAS')
plt.savefig('scatter_estancia_media_turistas.png')
plt.show()

# %%
dftotal[['TURISTAS', 'ESTANCIA_MEDIA']].plot(kind='box', subplots=True, layout=(1,2), figsize=(10,4), title='Boxplots de Turistas y Estancia Media')
plt.savefig('plot_estancia_media_turistas.png')
plt.show()

# %%
dftotal[['TURISTAS', 'PERNOCTACIONES']].plot(kind='box', subplots=True, layout=(1,2), figsize=(10,4), title='Boxplots de Turistas y Pernoctaciones')
plt.savefig('plot_pernoctaciones_turistas.png')
plt.show()

# %% [markdown]
# ### Análisis Multivariante

# %%
dftotal = dftotal.select_dtypes(exclude=['object'])
plt.savefig('heatmap.png')
sns.heatmap(dftotal.corr(), annot=True, annot_kws={"size": 9})
# Out:
# <Axes: >
